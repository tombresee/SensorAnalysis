# %% [markdown]
# # EXAMINING MATRIXPROFILE

# %% [markdown]
# ---

# %% [markdown]
# > https://matrixprofile.docs.matrixprofile.org/examples/NYC_Taxis.html

# %% [markdown]
# ---

# %%
import warnings
import warnings
warnings.filterwarnings("ignore")
import matrixprofile as mp
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
taxi = mp.datasets.load('nyc-taxi-anomalies')
ts = taxi['data']

# %%
ts
# Out:
# array([10844.,  8127.,  6210., ..., 27309., 26591., 26288.])

# %%
print(taxi)
# Out:
# {'name': 'nyc-taxi-anomalies.csv', 'category': 'real', 'description': 'Taxi passenger frequency from 2014-07-01 to 2015-01-31. The sample frequency is every 30 minutes consisting of 10,320 data points.', 'data': array([10844.,  8127.,  6210., ..., 27309., 26591., 26288.]), 'datetime': array(['2014-07-01T00:00:00', '2014-07-01T00:30:00',
#        '2014-07-01T01:00:00', ..., '2015-01-31T22:30:00',
#        '2015-01-31T23:00:00', '2015-01-31T23:30:00'],
#       dtype='datetime64[s]')}

# %%
type(taxi)
# Out:
# dict

# %%
taxi.keys()
# Out:
# dict_keys(['name', 'category', 'description', 'data', 'datetime'])

# %%
taxi['name']
# Out:
# 'nyc-taxi-anomalies.csv'

# %%
taxi['category']
# Out:
# 'real'

# %%
taxi['description']
# Out:
# 'Taxi passenger frequency from 2014-07-01 to 2015-01-31. The sample frequency is every 30 minutes consisting of 10,320 data points.'

# %%
len(taxi['datetime'])
# Out:
# 10320

# %%
taxi['datetime']
# Out:
# array(['2014-07-01T00:00:00', '2014-07-01T00:30:00',
#        '2014-07-01T01:00:00', ..., '2015-01-31T22:30:00',
#        '2015-01-31T23:00:00', '2015-01-31T23:30:00'],
#       dtype='datetime64[s]')

# %% [markdown]
# ---

# %%
# run analyze on all cpu cores
profile, figures = mp.analyze(ts, n_jobs=-1)
# Out:
# C:\Users\tbresee\Anaconda3\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# C:\Users\tbresee\Anaconda3\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# C:\Users\tbresee\Anaconda3\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
